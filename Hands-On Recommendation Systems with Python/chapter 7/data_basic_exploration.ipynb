# %%
import os 

import numpy as np
import pandas as pd

# %%
folder_path = "data/"
file_names = os.listdir(folder_path)

for file_name in file_names:
    print(file_name)
    display(pd.read_csv(folder_path + file_name).head())
# Out:
# ratings_small.csv
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205
# movies_metadata.csv
# /tmp/ipykernel_141790/271505081.py:6: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   display(pd.read_csv(folder_path + file_name).head())
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# ...

# %%
movies_metadata_df = pd.read_csv("data/movies_metadata.csv")
movies_metadata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100004 entries, 0 to 100003
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100004 non-null  int64
#  1   movieId    100004 non-null  int64
#  2   rating     100004 non-null  float64
#  3   timestamp  100004 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %% [markdown]
# ### Movie metadata data preparation and preprocessing

# %%
movies_metadata_df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
def convert_to_int(x):
    try:
        return int(x)
    except:
        return np.NaN

# %%
movies_metadata_df["movieId"] = movies_metadata_df["id"].apply(convert_to_int)

# %%
movies_metadata_df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
movies_metadata_df[movies_metadata_df["movieId"].isna()].shape[0]
# Out:
# 3

# %%
movies_metadata_df[movies_metadata_df["movieId"].isna()]
# Out:
#                                                    adult  \
# 19730                                 - Written by Ørnås
# 29503   Rune Balot goes to a casino connected to the ...
# 35587   Avalanche Sharks tells the story of a bikini ...
#
#       belongs_to_collection                            budget  \
# 19730              0.065736  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 29503              1.931659  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 35587              2.185485  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
#
#                                                   genres  \
# 19730  [{'name': 'Carousel Productions', 'id': 11176}...
# 29503  [{'name': 'Aniplex', 'id': 2883}, {'name': 'Go...
# 35587  [{'name': 'Odyssey Media', 'id': 17161}, {'nam...
#
#                                                 homepage          id imdb_id  \
# 19730  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  1997-08-20       0
# 29503  [{'iso_3166_1': 'US', 'name': 'United States o...  2012-09-29       0
# ...

# %% [markdown]
# **There are only 3 rows where id of the movie is in the form of date as shown above. Upon Closer Inspection, we can find that most of the values like original_title, title and overview are not clearly stated. Hence, we drop these rows.**

# %%
movies_metadata_df.dropna(subset=["movieId"], inplace=True)
movies_metadata_df.reset_index(drop=True, inplace=True)

# %%
movies_metadata_df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count', 'movieId'],
#       dtype='object')

# %%
relevant_columns = ["movieId", "original_title", "genres", "original_language", "overview", "production_companies", "production_countries"]
cleaned_metadata_df = movies_metadata_df[relevant_columns]
cleaned_metadata_df.head()
# Out:
#    movieId               original_title  \
# 0    862.0                    Toy Story
# 1   8844.0                      Jumanji
# 2  15602.0             Grumpier Old Men
# 3  31357.0            Waiting to Exhale
# 4  11862.0  Father of the Bride Part II
#
#                                               genres original_language  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...                en
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...                en
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...                en
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...                en
# 4                     [{'id': 35, 'name': 'Comedy'}]                en
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# ...

# %%
cleaned_metadata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45463 entries, 0 to 45462
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   movieId               45463 non-null  float64
#  1   original_title        45463 non-null  object
#  2   genres                45463 non-null  object
#  3   original_language     45452 non-null  object
#  4   overview              44509 non-null  object
#  5   production_companies  45460 non-null  object
#  6   production_countries  45460 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 2.4+ MB

# %%
from ast import literal_eval

def convert_obj_to_list(column):
    global cleaned_metadata_df
    cleaned_metadata_df[column] = cleaned_metadata_df[column].fillna('[]')
    cleaned_metadata_df[column] = cleaned_metadata_df[column].apply(literal_eval)
    cleaned_metadata_df[column] = cleaned_metadata_df[column].apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])

# %%
convert_obj_to_list("genres")
cleaned_metadata_df.head()
# Out:
# /tmp/ipykernel_141790/3696295991.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_metadata_df[column] = cleaned_metadata_df[column].fillna('[]')
# /tmp/ipykernel_141790/3696295991.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_metadata_df[column] = cleaned_metadata_df[column].apply(literal_eval)
# /tmp/ipykernel_141790/3696295991.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
convert_obj_to_list("production_companies")
convert_obj_to_list("production_countries")
cleaned_metadata_df.head()
# Out:
# /tmp/ipykernel_141790/3696295991.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_metadata_df[column] = cleaned_metadata_df[column].fillna('[]')
# /tmp/ipykernel_141790/3696295991.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_metadata_df[column] = cleaned_metadata_df[column].apply(literal_eval)
# /tmp/ipykernel_141790/3696295991.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
for column in ["genres", "production_companies", "production_countries"]:
    cleaned_metadata_df[column] = cleaned_metadata_df[column].apply(lambda x: " ".join(x))
cleaned_metadata_df.head()
# Out:
# /tmp/ipykernel_141790/3815544238.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_metadata_df[column] = cleaned_metadata_df[column].apply(lambda x: " ".join(x))
#    movieId               original_title                    genres  \
# 0    862.0                    Toy Story   Animation Comedy Family
# 1   8844.0                      Jumanji  Adventure Fantasy Family
# 2  15602.0             Grumpier Old Men            Romance Comedy
# 3  31357.0            Waiting to Exhale      Comedy Drama Romance
# 4  11862.0  Father of the Bride Part II                    Comedy
#
#   original_language                                           overview  \
# 0                en  Led by Woody, Andy's toys live happily in his ...
# ...

# %%
cleaned_metadata_df["movieId"] = cleaned_metadata_df["movieId"].astype(int)
cleaned_metadata_df.head()
# Out:
# /tmp/ipykernel_141790/2556783097.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_metadata_df["movieId"] = cleaned_metadata_df["movieId"].astype(int)
#    movieId               original_title                    genres  \
# 0      862                    Toy Story   Animation Comedy Family
# 1     8844                      Jumanji  Adventure Fantasy Family
# 2    15602             Grumpier Old Men            Romance Comedy
# 3    31357            Waiting to Exhale      Comedy Drama Romance
# 4    11862  Father of the Bride Part II                    Comedy
#
#   original_language                                           overview  \
# 0                en  Led by Woody, Andy's toys live happily in his ...
# ...

# %%
cleaned_metadata_df.to_csv("data/cleaned_movies_metadata.csv", index=False)

# %% [markdown]
# ### Cleaning ratings dataframe

# %%
ratings_df = pd.read_csv("data/ratings.csv")
ratings_df.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
ratings_df.drop(["timestamp"], axis=1, inplace=True)
ratings_df.head()
# Out:
#    userId  movieId  rating
# 0       1      110     1.0
# 1       1      147     4.5
# 2       1      858     5.0
# 3       1     1221     5.0
# 4       1     1246     5.0

# %%
ratings_df.to_csv("data/cleaned_ratings.csv", index=False)

# %%
metadata_id = set(cleaned_metadata_df["movieId"])
ratings_id = set(ratings_df["movieId"])
len(metadata_id), len(ratings_id)
# Out:
# (45433, 45115)

# %%
len(metadata_id - ratings_id)
# Out:
# 37868

# %%
len(ratings_id - metadata_id)
# Out:
# 37550

# %% [markdown]
# **here, only 7565 movies are rated. But other movies are not rated.**
