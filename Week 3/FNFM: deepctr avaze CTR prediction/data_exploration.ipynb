# %%
import pandas as pd

# %%
train = pd.read_pickle('./avazu/enc_train.pkl')
val = pd.read_pickle('./avazu/enc_val.pkl')
feature_count = pd.read_pickle('./avazu/feature_dic.pkl')
target = ['click']

# %%
test = pd.read_pickle('./avazu/enc_test.pkl')

# %%
type(train), type(val), type(test)
# Out:
# (pandas.core.frame.DataFrame,
#  pandas.core.frame.DataFrame,
#  pandas.core.frame.DataFrame)

# %%
display(train.head())
display(val.head())
display(test.head())
# Out:
#                     id  click  hour  C1  banner_pos  site_id  site_domain  \
# 19313925  6.597720e+18      0    17   2           1      831          276
# 28723675  1.696028e+19      0     9   2           0       58           52
# 8115694   1.642526e+19      0    15   2           0     1276         1308
# 32751022  1.106698e+19      0     3   2           0       58           52
# 22620735  7.677644e+18      0    14   2           1      958         1385
#
#           site_category  app_id  app_domain  ...  device_conn_type   C14 C15  \
# 19313925              6    1088           8  ...                 0   252   3
# 28723675             16     652         112  ...                 0  1278   3
# 8115694              18    1088           8  ...                 0   110   3
# 32751022             16     589          49  ...                 0  1537   3
# 22620735              1    1088           8  ...                 0   215   3
#
#           C16  C17  C18  C19  C20  C21  day
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3620824 entries, 19313925 to 18583429
# Data columns (total 25 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   id                float64
#  1   click             int64
#  2   hour              int64
#  3   C1                int64
#  4   banner_pos        int64
#  5   site_id           int64
#  6   site_domain       int64
#  7   site_category     int64
#  8   app_id            int64
#  9   app_domain        int64
#  10  app_category      int64
#  11  device_id         object
#  12  device_ip         object
#  13  device_model      int64
#  14  device_type       int64
#  15  device_conn_type  int64
#  16  C14               int64
#  17  C15               int64
#  18  C16               int64
#  19  C17               int64
#  20  C18               int64
#  21  C19               int64
#  22  C20               int64
#  23  C21               int64
#  24  day               int64
# ...

# %%
print(train["device_ip"][:2])
print()
train["device_ip"].nunique(), len(train["device_ip"])
# Out:
# 19313925    1bdf6ca9
# 28723675    7de40262
# Name: device_ip, dtype: object
# (1476650, 3620824)

# %%
print(train["device_id"][:2])
# Out:
# 19313925    a99f214a
# 28723675    a99f214a
# Name: device_id, dtype: object

# %%
feature_count
# Out:
# {'C1': 7,
#  'banner_pos': 7,
#  'site_id': 1896,
#  'site_domain': 1719,
#  'site_category': 22,
#  'app_id': 1673,
#  'app_domain': 115,
#  'app_category': 27,
#  'device_model': 3931,
#  'device_type': 5,
#  'device_conn_type': 4,
#  'C14': 1981,
#  'C15': 8,
#  'C16': 9,
#  'C17': 415,
#  'C18': 4,
#  'C19': 66,
#  'C20': 159,
#  'C21': 60,
#  'hour': 24}

# %%
train.C1.nunique(), train.device_model.nunique()
# Out:
# (7, 3930)
