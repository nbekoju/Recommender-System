# %%
import pandas as pd
from recbole.quick_start import run_recbole

# %%
file_path = "dataset/movie/movie.inter"
df = pd.read_csv('dataset/movie/movie.inter', sep="\t")

# %%
df.head()
# Out:
#    user_id:token  item_id:token  rating:float  timestamp:float
# 0            196            242             3        881250949
# 1            186            302             3        891717742
# 2             22            377             1        878887116
# 3            244             51             2        880606923
# 4            166            346             1        886397596

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 4 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   user_id:token    100000 non-null  int64
#  1   item_id:token    100000 non-null  int64
#  2   rating:float     100000 non-null  int64
#  3   timestamp:float  100000 non-null  int64
# dtypes: int64(4)
# memory usage: 3.1 MB

# %%
run_recbole(model="GRU4Rec", dataset="movie", config_file_list=["custom_config.yaml"])
# Out:
# 30 May 10:20    INFO  ['/home/niranjan/miniconda3/envs/recbole/lib/python3.9/site-packages/ipykernel_launcher.py', '--f=/home/niranjan/.local/share/jupyter/runtime/kernel-v2-20041r6CCi5B3KVuD.json']
# 30 May 10:20    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/movie
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 50
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step
#  = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# ...

# %% [markdown]
# ### Load the saved model

# %%
model_path = "saved/GRU4Rec-May-30-2024_10-20-04.pth"
